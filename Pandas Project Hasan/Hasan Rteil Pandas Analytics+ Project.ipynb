# %% [markdown]
# # Analyze Supermarket Data Across the Country - Company XYZ
#
# Company XYZ owns a supermarket chain across the country. Each major branch located in 3 cities across the country recorded sales information for 3 months, to help the company understand sales trends and determine its growth, as the rise of supermarkets competition is seen.

# %% [markdown]
# You will apply learnings to analyse the dataset in the data folder, and the description of each feature can be found in this [link](https://docs.google.com/document/d/1Sv-DlynHpOBAs5qKokn5MtbzqZcumTSlSI4-wQ0kf0w/edit?usp=sharing)

# %% [markdown]
# ## Step 1 - Loading the Dataset
# In this step, you will combine the dataset from each branch (3 branches) into one dataset for easy analysis. You expected to write the syntaxes that will read multiple files from your current working directory and export a CSV file after combining.
# The learning from this step is the ability to automate reading and combining multiple CSV files, because as a Data Professional, you will saddled with the responsibility of reading data from different sources, and this is one of the use case.

# %% [markdown]
# #### To-Do - Import Libraries

# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\\user\\Pandas Project Hasan") #Current working directory that contains your dataset and code file
os.getcwd()
# Out:
# 'C:\\Users\\user\\Pandas Project Hasan'

# %% [markdown]
# #### To-Do - Use glob to match the pattern "csv"

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob(f"*{extension}")]
print(all_filenames)
# Out:
# ['Abuja_Branch.csv', 'combinefiles.csv', 'Lagos_Branch.csv', 'Port_Harcourt_Branch.csv']

# %% [markdown]
# #### To-Do - Combine all the files in the generated list above and export to a CSV
# Tips - Use the `pd.concat` method

# %%
combine_files = pd.concat(
    map(pd.read_csv, (all_filenames)), ignore_index = True)
print(combine_files)

#Export to csv

combine_files.to_csv('combinefiles.csv')
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 5995  148-41-7930      C  Port Harcourt        Normal    Male
# 5996  189-40-5216      C  Port Harcourt        Normal    Male
# 5997  267-62-7380      C  Port Harcourt        Member    Male
# 5998  652-49-6720      C  Port Harcourt        Member  Female
# 5999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# 2     Electronic accessories      9183.6         4   1836.72   38571.12
# 3          Sports and travel     33739.2         6  10121.76  212556.96
# 4         Home and lifestyle     14508.0         2   1450.80   30466.80
# ...                      ...         ...       ...       ...        ...
# 5995       Health and beauty     35985.6         7  12594.96  264494.16
# 5996  Electronic accessories     34693.2         7  12142.62  254995.02
# 5997  Electronic accessories     29642.4        10  14821.20  311245.20
# 5998  Electronic accessories     21942.0         1   1097.10   23039.10
# 5999       Health and beauty     14526.0         1    726.30   15252.30
#
#            Date   Time Payment      cogs  gross margin percentage  \
# 0     2/20/2019  13:27    Card   59227.2                 4.761905
# 1      2/6/2019  18:07    Epay   20851.2                 4.761905
# 2      3/9/2019  17:03    Cash   36734.4                 4.761905
# 3     1/15/2019  16:19    Cash  202435.2                 4.761905
# 4     3/11/2019  15:30    Epay   29016.0                 4.761905
# ...         ...    ...     ...       ...                      ...
# 5995  1/23/2019  10:33    Cash  251899.2                 4.761905
# 5996   1/9/2019  11:40    Cash  242852.4                 4.761905
# 5997  3/29/2019  19:12    Epay  296424.0                 4.761905
# 5998  2/18/2019  11:40    Epay   21942.0                 4.761905
# 5999  1/29/2019  13:46    Epay   14526.0                 4.761905
#
#       gross income  Rating  Unnamed: 0
# 0          2961.36     5.9         NaN
# 1          1042.56     4.5         NaN
# 2          1836.72     6.8         NaN
# 3         10121.76     4.5         NaN
# 4          1450.80     4.4         NaN
# ...            ...     ...         ...
# 5995      12594.96     6.1         NaN
# 5996      12142.62     6.0         NaN
# 5997      14821.20     4.3         NaN
# 5998       1097.10     5.9         NaN
# 5999        726.30     6.2         NaN
#
# [6000 rows x 18 columns]

# %% [markdown]
# #### To-Do -Read the CSV file using `pd.read_csv` method

# %%
pd.read_csv('combinefiles.csv')
# Out:
#       Unnamed: 0.1   Invoice ID Branch           City Customer type  Gender  \
# 0                0  692-92-5582      B          Abuja        Member  Female
# 1                1  351-62-0822      B          Abuja        Member  Female
# 2                2  529-56-3974      B          Abuja        Member    Male
# 3                3  299-46-1805      B          Abuja        Member  Female
# 4                4  319-50-3348      B          Abuja        Normal  Female
# ...            ...          ...    ...            ...           ...     ...
# 5995          5995  148-41-7930      C  Port Harcourt        Normal    Male
# 5996          5996  189-40-5216      C  Port Harcourt        Normal    Male
# 5997          5997  267-62-7380      C  Port Harcourt        Member    Male
# 5998          5998  652-49-6720      C  Port Harcourt        Member  Female
# 5999          5999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# 2     Electronic accessories      9183.6         4   1836.72   38571.12
# 3          Sports and travel     33739.2         6  10121.76  212556.96
# 4         Home and lifestyle     14508.0         2   1450.80   30466.80
# ...                      ...         ...       ...       ...        ...
# 5995       Health and beauty     35985.6         7  12594.96  264494.16
# 5996  Electronic accessories     34693.2         7  12142.62  254995.02
# 5997  Electronic accessories     29642.4        10  14821.20  311245.20
# 5998  Electronic accessories     21942.0         1   1097.10   23039.10
# 5999       Health and beauty     14526.0         1    726.30   15252.30
#
#            Date   Time Payment      cogs  gross margin percentage  \
# 0     2/20/2019  13:27    Card   59227.2                 4.761905
# 1      2/6/2019  18:07    Epay   20851.2                 4.761905
# 2      3/9/2019  17:03    Cash   36734.4                 4.761905
# 3     1/15/2019  16:19    Cash  202435.2                 4.761905
# 4     3/11/2019  15:30    Epay   29016.0                 4.761905
# ...         ...    ...     ...       ...                      ...
# 5995  1/23/2019  10:33    Cash  251899.2                 4.761905
# 5996   1/9/2019  11:40    Cash  242852.4                 4.761905
# 5997  3/29/2019  19:12    Epay  296424.0                 4.761905
# 5998  2/18/2019  11:40    Epay   21942.0                 4.761905
# 5999  1/29/2019  13:46    Epay   14526.0                 4.761905
#
#       gross income  Rating  Unnamed: 0
# 0          2961.36     5.9         NaN
# 1          1042.56     4.5         NaN
# 2          1836.72     6.8         NaN
# 3         10121.76     4.5         NaN
# 4          1450.80     4.4         NaN
# ...            ...     ...         ...
# 5995      12594.96     6.1         NaN
# 5996      12142.62     6.0         NaN
# 5997      14821.20     4.3         NaN
# 5998       1097.10     5.9         NaN
# 5999        726.30     6.2         NaN
#
# [6000 rows x 19 columns]

# %% [markdown]
# ## Step 2 - Data Exploration
# In this step you will explore the loaded dataset using some built-in Pandas function. You expected to begin to think about your analytical approach from here.
# You can include other methods that you might think will make your exploration process easier. For Instance, you can write a function that print out a summary of the missing data occurence in the data. Be sure to document these methods using `markdown` and in-line `comments`.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from datetime import time
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### To-Do - Use the head() method to view first few rows of the dataset

# %%
combinefiles = pd.read_csv('combinefiles.csv')
combinefiles.head(5)
# Out:
#    Unnamed: 0.1   Invoice ID Branch   City Customer type  Gender  \
# 0             0  692-92-5582      B  Abuja        Member  Female
# 1             1  351-62-0822      B  Abuja        Member  Female
# 2             2  529-56-3974      B  Abuja        Member    Male
# 3             3  299-46-1805      B  Abuja        Member  Female
# 4             4  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0      Food and beverages     19742.4         3   2961.36   62188.56
# 1     Fashion accessories      5212.8         4   1042.56   21893.76
# 2  Electronic accessories      9183.6         4   1836.72   38571.12
# 3       Sports and travel     33739.2         6  10121.76  212556.96
# 4      Home and lifestyle     14508.0         2   1450.80   30466.80
#
#         Date   Time Payment      cogs  gross margin percentage  gross income  \
# 0  2/20/2019  13:27    Card   59227.2                 4.761905       2961.36
# 1   2/6/2019  18:07    Epay   20851.2                 4.761905       1042.56
# 2   3/9/2019  17:03    Cash   36734.4                 4.761905       1836.72
# 3  1/15/2019  16:19    Cash  202435.2                 4.761905      10121.76
# 4  3/11/2019  15:30    Epay   29016.0                 4.761905       1450.80
#
#    Rating  Unnamed: 0
# 0     5.9         NaN
# 1     4.5         NaN
# 2     6.8         NaN
# 3     4.5         NaN
# 4     4.4         NaN

# %% [markdown]
# #### To-Do - Check the number of rows and columns present in the data using the shape attribute.

# %%
combinefiles.shape
# Out:
# (6000, 19)

# %% [markdown]
# #### To-Do - Generate the names of the columns using the columns attribute.

# %%
col_names = pd.read_csv("combinefiles.csv")
list(col_names.columns)
# Out:
# ['Unnamed: 0.1',
#  'Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating',
#  'Unnamed: 0']

# %% [markdown]
# #### To-Do - Statiscal Summary
# The describe method provides the data statistical summary for the dataset, use the method to explore the statistical summary.

# %%
combinefiles.describe()
# Out:
#        Unnamed: 0.1   Unit price     Quantity       Tax 5%          Total  \
# count   6000.000000   6000.00000  6000.000000   6000.00000    6000.000000
# mean    2999.500000  20041.96680     5.510000   5536.57284  116268.029640
# std     1732.195139   9534.09052     2.922212   4213.42019   88481.823998
# min        0.000000   3628.80000     1.000000    183.06000    3844.260000
# 25%     1499.750000  11835.00000     3.000000   2132.95500   44792.055000
# 50%     2999.500000  19882.80000     5.000000   4351.68000   91385.280000
# 75%     4499.250000  28056.60000     8.000000   8080.29000  169686.090000
# max     5999.000000  35985.60000    10.000000  17874.00000  375354.000000
#
#                 cogs  gross margin percentage  gross income       Rating  \
# count    6000.000000             6.000000e+03    6000.00000  6000.000000
# mean   110731.456800             4.761905e+00    5536.57284     6.972700
# std     84268.403808             5.675933e-13    4213.42019     1.717864
# min      3661.200000             4.761905e+00     183.06000     4.000000
# 25%     42659.100000             4.761905e+00    2132.95500     5.500000
# 50%     87033.600000             4.761905e+00    4351.68000     7.000000
# 75%    161605.800000             4.761905e+00    8080.29000     8.500000
# max    357480.000000             4.761905e+00   17874.00000    10.000000
#
#         Unnamed: 0
# count  5000.000000
# mean   2499.500000
# std    1443.520003
# min       0.000000
# 25%    1249.750000
# 50%    2499.500000
# 75%    3749.250000
# max    4999.000000

# %% [markdown]
# #### To-Do - Below this cell write in few sentences what you can derive from the data statistical summary

# %%
#There is no missing values in the dataset
#The max rating is 10
#Average quantity is 5.51

# %% [markdown]
# #### To-Do - Missing values
# The `isnull`, and `notna` methods can provide a quick overview of the missing data occurence, use that to observe the presence of missing data in the dataset. You can add the sum method to get a summary and not boolean values.

# %%
combinefiles.isnull().sum()
# Out:
# Unnamed: 0.1                  0
# Invoice ID                    0
# Branch                        0
# City                          0
# Customer type                 0
# Gender                        0
# Product line                  0
# Unit price                    0
# Quantity                      0
# Tax 5%                        0
# Total                         0
# Date                          0
# Time                          0
# Payment                       0
# cogs                          0
# gross margin percentage       0
# gross income                  0
# Rating                        0
# Unnamed: 0                 1000
# Day                           0
# Month                         0
# Year                          0
# Hour                          0
# dtype: int64

# %% [markdown]
# #### To-Do - Data Information
# The `info()` function is used to print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage. Use this method to observe the data type of each feature.

# %%
combinefiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             6000 non-null   int64
#  1   Invoice ID               6000 non-null   object
#  2   Branch                   6000 non-null   object
#  3   City                     6000 non-null   object
#  4   Customer type            6000 non-null   object
#  5   Gender                   6000 non-null   object
#  6   Product line             6000 non-null   object
#  7   Unit price               6000 non-null   float64
#  8   Quantity                 6000 non-null   int64
#  9   Tax 5%                   6000 non-null   float64
#  10  Total                    6000 non-null   float64
#  11  Date                     6000 non-null   object
#  12  Time                     6000 non-null   object
#  13  Payment                  6000 non-null   object
#  14  cogs                     6000 non-null   float64
#  15  gross margin percentage  6000 non-null   float64
#  16  gross income             6000 non-null   float64
#  17  Rating                   6000 non-null   float64
#  18  Unnamed: 0               5000 non-null   float64
# dtypes: float64(8), int64(2), object(9)
# memory usage: 890.8+ KB

# %% [markdown]
# ## Step 3 - Dealing with DateTime Features

# %% [markdown]
# From the summary above, you can observe that the `date` and `time` columns are not in the appropriate data type
# you can convert to `datetime` datatype using the `to_datetime()` method. After that is done, use the type attribute
# to confirm the datatype.

# %% [markdown]
# #### To-Do - Use `to_datetime()` to convert the `date` column to `datetime`

# %%
combinefiles["Date"]= pd.to_datetime(combinefiles["Date"])

# %% [markdown]
# #### To-Do - Check the datatype to confirm if it's in `datetime`

# %%
combinefiles.Date.dtypes
combinefiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             6000 non-null   int64
#  1   Invoice ID               6000 non-null   object
#  2   Branch                   6000 non-null   object
#  3   City                     6000 non-null   object
#  4   Customer type            6000 non-null   object
#  5   Gender                   6000 non-null   object
#  6   Product line             6000 non-null   object
#  7   Unit price               6000 non-null   float64
#  8   Quantity                 6000 non-null   int64
#  9   Tax 5%                   6000 non-null   float64
#  10  Total                    6000 non-null   float64
#  11  Date                     6000 non-null   datetime64[ns]
#  12  Time                     6000 non-null   object
#  13  Payment                  6000 non-null   object
#  14  cogs                     6000 non-null   float64
#  15  gross margin percentage  6000 non-null   float64
#  16  gross income             6000 non-null   float64
#  17  Rating                   6000 non-null   float64
#  18  Unnamed: 0               5000 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(8)
# memory usage: 890.8+ KB

# %% [markdown]
# #### To-Do - Repeat the two steps above to the `time` column

# %%
combinefiles['Time'] = pd.to_datetime(combinefiles['Time'])
combinefiles.Date.dtypes
combinefiles.info()
combinefiles.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             6000 non-null   int64
#  1   Invoice ID               6000 non-null   object
#  2   Branch                   6000 non-null   object
#  3   City                     6000 non-null   object
#  4   Customer type            6000 non-null   object
#  5   Gender                   6000 non-null   object
#  6   Product line             6000 non-null   object
#  7   Unit price               6000 non-null   float64
#  8   Quantity                 6000 non-null   int64
#  9   Tax 5%                   6000 non-null   float64
#  10  Total                    6000 non-null   float64
#  11  Date                     6000 non-null   datetime64[ns]
#  12  Time                     6000 non-null   datetime64[ns]
#  13  Payment                  6000 non-null   object
#  14  cogs                     6000 non-null   float64
#  15  gross margin percentage  6000 non-null   float64
#  16  gross income             6000 non-null   float64
#  17  Rating                   6000 non-null   float64
#  18  Unnamed: 0               5000 non-null   float64
# dtypes: datetime64[ns](2), float64(8), int64(2), object(7)
# memory usage: 890.8+ KB
#    Unnamed: 0.1   Invoice ID Branch   City Customer type  Gender  \
# 0             0  692-92-5582      B  Abuja        Member  Female
# 1             1  351-62-0822      B  Abuja        Member  Female
# 2             2  529-56-3974      B  Abuja        Member    Male
# 3             3  299-46-1805      B  Abuja        Member  Female
# 4             4  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0      Food and beverages     19742.4         3   2961.36   62188.56
# 1     Fashion accessories      5212.8         4   1042.56   21893.76
# 2  Electronic accessories      9183.6         4   1836.72   38571.12
# 3       Sports and travel     33739.2         6  10121.76  212556.96
# 4      Home and lifestyle     14508.0         2   1450.80   30466.80
#
#         Date                Time Payment      cogs  gross margin percentage  \
# 0 2019-02-20 2022-09-21 13:27:00    Card   59227.2                 4.761905
# 1 2019-02-06 2022-09-21 18:07:00    Epay   20851.2                 4.761905
# 2 2019-03-09 2022-09-21 17:03:00    Cash   36734.4                 4.761905
# 3 2019-01-15 2022-09-21 16:19:00    Cash  202435.2                 4.761905
# 4 2019-03-11 2022-09-21 15:30:00    Epay   29016.0                 4.761905
#
#    gross income  Rating  Unnamed: 0
# 0       2961.36     5.9         NaN
# 1       1042.56     4.5         NaN
# 2       1836.72     6.8         NaN
# 3      10121.76     4.5         NaN
# 4       1450.80     4.4         NaN

# %% [markdown]
# ## Extract Features from date & time

# %% [markdown]
# #### To-Do - Extract the Day feature from the `Date` column, and save to a new `Day` column

# %%
combinefiles['Day'] = combinefiles.Date.dt.day
combinefiles.head()
# Out:
#    Unnamed: 0.1   Invoice ID Branch   City Customer type  Gender  \
# 0             0  692-92-5582      B  Abuja        Member  Female
# 1             1  351-62-0822      B  Abuja        Member  Female
# 2             2  529-56-3974      B  Abuja        Member    Male
# 3             3  299-46-1805      B  Abuja        Member  Female
# 4             4  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0      Food and beverages     19742.4         3   2961.36   62188.56
# 1     Fashion accessories      5212.8         4   1042.56   21893.76
# 2  Electronic accessories      9183.6         4   1836.72   38571.12
# 3       Sports and travel     33739.2         6  10121.76  212556.96
# 4      Home and lifestyle     14508.0         2   1450.80   30466.80
#
#         Date                Time Payment      cogs  gross margin percentage  \
# 0 2019-02-20 2022-09-21 13:27:00    Card   59227.2                 4.761905
# 1 2019-02-06 2022-09-21 18:07:00    Epay   20851.2                 4.761905
# 2 2019-03-09 2022-09-21 17:03:00    Cash   36734.4                 4.761905
# 3 2019-01-15 2022-09-21 16:19:00    Cash  202435.2                 4.761905
# 4 2019-03-11 2022-09-21 15:30:00    Epay   29016.0                 4.761905
#
#    gross income  Rating  Unnamed: 0  Day
# 0       2961.36     5.9         NaN   20
# 1       1042.56     4.5         NaN    6
# 2       1836.72     6.8         NaN    9
# 3      10121.76     4.5         NaN   15
# 4       1450.80     4.4         NaN   11

# %% [markdown]
# #### To-Do - Extract the Month feature from the `Date` column, and save to a new `Month` column

# %%
combinefiles['Month'] = combinefiles.Date.dt.month
combinefiles.head()
# Out:
#    Unnamed: 0.1   Invoice ID Branch   City Customer type  Gender  \
# 0             0  692-92-5582      B  Abuja        Member  Female
# 1             1  351-62-0822      B  Abuja        Member  Female
# 2             2  529-56-3974      B  Abuja        Member    Male
# 3             3  299-46-1805      B  Abuja        Member  Female
# 4             4  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%  ...       Date  \
# 0      Food and beverages     19742.4         3   2961.36  ... 2019-02-20
# 1     Fashion accessories      5212.8         4   1042.56  ... 2019-02-06
# 2  Electronic accessories      9183.6         4   1836.72  ... 2019-03-09
# 3       Sports and travel     33739.2         6  10121.76  ... 2019-01-15
# 4      Home and lifestyle     14508.0         2   1450.80  ... 2019-03-11
#
#                  Time Payment      cogs  gross margin percentage  \
# 0 2022-09-21 13:27:00    Card   59227.2                 4.761905
# 1 2022-09-21 18:07:00    Epay   20851.2                 4.761905
# 2 2022-09-21 17:03:00    Cash   36734.4                 4.761905
# 3 2022-09-21 16:19:00    Cash  202435.2                 4.761905
# 4 2022-09-21 15:30:00    Epay   29016.0                 4.761905
#
#    gross income  Rating  Unnamed: 0  Day  Month
# 0       2961.36     5.9         NaN   20      2
# 1       1042.56     4.5         NaN    6      2
# 2       1836.72     6.8         NaN    9      3
# 3      10121.76     4.5         NaN   15      1
# 4       1450.80     4.4         NaN   11      3
#
# [5 rows x 21 columns]

# %% [markdown]
# #### To-Do -Extract the Year feature from the `Date` column, and save to a new `Year` column

# %%
combinefiles['Year'] = combinefiles.Date.dt.year
combinefiles.head()
# Out:
#    Unnamed: 0.1   Invoice ID Branch   City Customer type  Gender  \
# 0             0  692-92-5582      B  Abuja        Member  Female
# 1             1  351-62-0822      B  Abuja        Member  Female
# 2             2  529-56-3974      B  Abuja        Member    Male
# 3             3  299-46-1805      B  Abuja        Member  Female
# 4             4  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%  ...  \
# 0      Food and beverages     19742.4         3   2961.36  ...
# 1     Fashion accessories      5212.8         4   1042.56  ...
# 2  Electronic accessories      9183.6         4   1836.72  ...
# 3       Sports and travel     33739.2         6  10121.76  ...
# 4      Home and lifestyle     14508.0         2   1450.80  ...
#
#                  Time Payment      cogs gross margin percentage  gross income  \
# 0 2022-09-21 13:27:00    Card   59227.2                4.761905       2961.36
# 1 2022-09-21 18:07:00    Epay   20851.2                4.761905       1042.56
# 2 2022-09-21 17:03:00    Cash   36734.4                4.761905       1836.72
# 3 2022-09-21 16:19:00    Cash  202435.2                4.761905      10121.76
# 4 2022-09-21 15:30:00    Epay   29016.0                4.761905       1450.80
#
#    Rating  Unnamed: 0  Day  Month  Year
# 0     5.9         NaN   20      2  2019
# 1     4.5         NaN    6      2  2019
# 2     6.8         NaN    9      3  2019
# 3     4.5         NaN   15      1  2019
# 4     4.4         NaN   11      3  2019
#
# [5 rows x 22 columns]

# %% [markdown]
# #### To-Do - Extract the `Hour` feature from the `Time` column and save to a new `Hour` column

# %%
combinefiles['Hour'] = combinefiles.Time.dt.hour
combinefiles.head()
# Out:
#    Unnamed: 0.1   Invoice ID Branch   City Customer type  Gender  \
# 0             0  692-92-5582      B  Abuja        Member  Female
# 1             1  351-62-0822      B  Abuja        Member  Female
# 2             2  529-56-3974      B  Abuja        Member    Male
# 3             3  299-46-1805      B  Abuja        Member  Female
# 4             4  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%  ...  Payment  \
# 0      Food and beverages     19742.4         3   2961.36  ...     Card
# 1     Fashion accessories      5212.8         4   1042.56  ...     Epay
# 2  Electronic accessories      9183.6         4   1836.72  ...     Cash
# 3       Sports and travel     33739.2         6  10121.76  ...     Cash
# 4      Home and lifestyle     14508.0         2   1450.80  ...     Epay
#
#        cogs gross margin percentage gross income  Rating  Unnamed: 0  Day  \
# 0   59227.2                4.761905      2961.36     5.9         NaN   20
# 1   20851.2                4.761905      1042.56     4.5         NaN    6
# 2   36734.4                4.761905      1836.72     6.8         NaN    9
# 3  202435.2                4.761905     10121.76     4.5         NaN   15
# 4   29016.0                4.761905      1450.80     4.4         NaN   11
#
#    Month  Year  Hour
# 0      2  2019    13
# 1      2  2019    18
# 2      3  2019    17
# 3      1  2019    16
# 4      3  2019    15
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Pandas provide the `nunique()` method to get a count of unique values, while the `unique()` function is used to get unique values of Series object.

# %% [markdown]
# #### To-Do -  From the hours information, determine the numbers of unique hours of sales in the supermarket, and return an array of the hours using the unique() method

# %%
combinefiles['Time'].unique()
# Out:
# array(['2022-09-21T13:27:00.000000000', '2022-09-21T18:07:00.000000000',
#        '2022-09-21T17:03:00.000000000', '2022-09-21T16:19:00.000000000',
#        '2022-09-21T15:30:00.000000000', '2022-09-21T10:40:00.000000000',
#        '2022-09-21T12:20:00.000000000', '2022-09-21T15:31:00.000000000',
#        '2022-09-21T19:48:00.000000000', '2022-09-21T19:39:00.000000000',
#        '2022-09-21T12:43:00.000000000', '2022-09-21T14:49:00.000000000',
#        '2022-09-21T13:01:00.000000000', '2022-09-21T18:45:00.000000000',
#        '2022-09-21T13:03:00.000000000', '2022-09-21T18:00:00.000000000',
#        '2022-09-21T17:24:00.000000000', '2022-09-21T15:47:00.000000000',
#        '2022-09-21T12:45:00.000000000', '2022-09-21T14:42:00.000000000',
#        '2022-09-21T11:49:00.000000000', '2022-09-21T13:40:00.000000000',
#        '2022-09-21T14:35:00.000000000', '2022-09-21T15:01:00.000000000',
#        '2022-09-21T18:17:00.000000000', '2022-09-21T19:56:00.000000000',
#        '2022-09-21T17:55:00.000000000', '2022-09-21T12:09:00.000000000',
#        '2022-09-21T10:25:00.000000000', '2022-09-21T18:14:00.000000000',
#        '2022-09-21T18:19:00.000000000', '2022-09-21T11:32:00.000000000',
#        '2022-09-21T12:44:00.000000000', '2022-09-21T12:29:00.000000000',
#        '2022-09-21T15:26:00.000000000', '2022-09-21T20:38:00.000000000',
#        '2022-09-21T17:26:00.000000000', '2022-09-21T14:57:00.000000000',
#        '2022-09-21T11:15:00.000000000', '2022-09-21T13:18:00.000000000',
#        '2022-09-21T18:36:00.000000000', '2022-09-21T14:40:00.000000000',
#        '2022-09-21T12:21:00.000000000', '2022-09-21T15:07:00.000000000',
#        '2022-09-21T19:20:00.000000000', '2022-09-21T19:40:00.000000000',
#        '2022-09-21T13:58:00.000000000', '2022-09-21T14:43:00.000000000',
#        '2022-09-21T19:18:00.000000000', '2022-09-21T15:24:00.000000000',
#        '2022-09-21T14:12:00.000000000', '2022-09-21T17:34:00.000000000',
#        '2022-09-21T12:04:00.000000000', '2022-09-21T19:46:00.000000000',
#        '2022-09-21T19:00:00.000000000', '2022-09-21T10:53:00.000000000',
#        '2022-09-21T10:39:00.000000000', '2022-09-21T13:41:00.000000000',
#        '2022-09-21T20:23:00.000000000', '2022-09-21T11:57:00.000000000',
#        '2022-09-21T14:51:00.000000000', '2022-09-21T12:42:00.000000000',
#        '2022-09-21T19:42:00.000000000', '2022-09-21T19:17:00.000000000',
#        '2022-09-21T20:15:00.000000000', '2022-09-21T14:11:00.000000000',
#        '2022-09-21T12:10:00.000000000', '2022-09-21T20:47:00.000000000',
#        '2022-09-21T11:17:00.000000000', '2022-09-21T15:52:00.000000000',
#        '2022-09-21T11:43:00.000000000', '2022-09-21T10:30:00.000000000',
#        '2022-09-21T10:06:00.000000000', '2022-09-21T12:16:00.000000000',
#        '2022-09-21T14:58:00.000000000', '2022-09-21T14:45:00.000000000',
#        '2022-09-21T17:10:00.000000000', '2022-09-21T14:27:00.000000000',
#        '2022-09-21T12:51:00.000000000', '2022-09-21T13:56:00.000000000',
#        '2022-09-21T16:18:00.000000000', '2022-09-21T15:14:00.000000000',
#        '2022-09-21T20:10:00.000000000', '2022-09-21T14:24:00.000000000',
#        '2022-09-21T12:39:00.000000000', '2022-09-21T12:41:00.000000000',
#        '2022-09-21T15:20:00.000000000', '2022-09-21T16:33:00.000000000',
#        '2022-09-21T20:44:00.000000000', '2022-09-21T20:30:00.000000000',
#        '2022-09-21T16:50:00.000000000', '2022-09-21T17:52:00.000000000',
#        '2022-09-21T11:33:00.000000000', '2022-09-21T18:38:00.000000000',
#        '2022-09-21T15:11:00.000000000', '2022-09-21T15:45:00.000000000',
#        '2022-09-21T16:35:00.000000000', '2022-09-21T13:50:00.000000000',
#        '2022-09-21T17:56:00.000000000', '2022-09-21T13:49:00.000000000',
#        '2022-09-21T14:05:00.000000000', '2022-09-21T19:12:00.000000000'],
#       dtype='datetime64[ns]')

# %%
#[Write your Code Here]

# %% [markdown]
# ## Step 4 - Unique Values in Columns

# %% [markdown]
# With the line of code below, we can get a list of the categorical column in the dataset. We iterate through the columns and check if each element is an object datatype. The result is saved to the "categorical_columns" variable
# as a list.

# %%
#Uncomment the code and Run it
categorical_columns = [col for col in combinefiles.columns if combinefiles[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %% [markdown]
# #### To-Do- From the information above, generate the unique values in the categorical columns (apart from the example - Branch column).
# For example, the unique values of the "Branch" column is displayed in list, as shown below.
# <br/>
# `df['Branch'].unique().tolist()
# ['B', 'C', 'A']`
# </br>
# <br/>
# You can add print formating syntax to print out the total numbers of these values in a particular column.

# %%
#Example - Uncomment the Code and Run it
#combinefiles['Branch'].unique().tolist()


for i in categorical_columns:
    if i != 'Invoice ID':
       print ("For {} Columns".format(i))
       print (combinefiles[i].unique().tolist())
# Out:
# For Branch Columns
# ['B', 'A', 'C']
# For City Columns
# ['Abuja', 'Lagos', 'Port Harcourt']
# For Customer type Columns
# ['Member', 'Normal']
# For Gender Columns
# ['Female', 'Male']
# For Product line Columns
# ['Food and beverages', 'Fashion accessories', 'Electronic accessories', 'Sports and travel', 'Home and lifestyle', 'Health and beauty']
# For Payment Columns
# ['Card', 'Epay', 'Cash']

# %% [markdown]
# #### To-Do: The `value_counts()` function is used to get a Series containing counts of unique values. For the categorical columns above, generate the count figure of the values using the `value_counts() ` method.

# %%
#Example
#df['City'].value_counts()
for i in categorical_columns:
    if i != 'Invoice ID':
        print ("This is for {} Columns".format(i))
        print ("Total Number of unique value: {}". format(len(combinefiles[i].value_counts().tolist())))
        
combinefiles['Payment'].value_counts()
# Out:
# This is for Branch Columns
# Total Number of unique value: 3
# This is for City Columns
# Total Number of unique value: 3
# This is for Customer type Columns
# Total Number of unique value: 2
# This is for Gender Columns
# Total Number of unique value: 2
# This is for Product line Columns
# Total Number of unique value: 6
# This is for Payment Columns
# Total Number of unique value: 3
# Epay    2070
# Cash    2064
# Card    1866
# Name: Payment, dtype: int64

# %% [markdown]
# ## Step 5 - Aggregration with GroupBy

# %% [markdown]
# #### To-Do - Your task here, will be to create a groupby object with the "City Column", and aggregation function of sum and mean.

# %%
by_city = combinefiles.groupby("City")
by_city.agg(["sum", "mean"])
# Out:
#               Unnamed: 0.1          Unit price               Quantity  \
#                        sum    mean         sum          mean      sum
# City
# Abuja              1983036   995.5  39914380.8  20037.339759    10920
# Lagos              7816260  3831.5  40231058.4  19721.107059    11154
# Port Harcourt      8197704  4165.5  40106361.6  20379.248780    10986
#
#                               Tax 5%                      Total  \
#                    mean          sum         mean           sum
# City
# Abuja          5.481928  10923189.12  5483.528675  2.293870e+08
# Lagos          5.467647  10923466.68  5354.640529  2.293928e+08
# Port Harcourt  5.582317  11372781.24  5778.852256  2.388284e+08
#
#                               ... Unnamed: 0            Day            Month  \
#                         mean  ...        sum    mean    sum       mean   sum
# City                          ...
# Abuja          115154.102169  ...  1376970.0   829.5  30408  15.265060  3990
# Lagos          112447.451118  ...  5381350.0  3165.5  31392  15.388235  4128
# Port Harcourt  121355.897378  ...  5739180.0  3499.5  29736  15.109756  3840
#
#                             Year           Hour
#                    mean      sum    mean    sum       mean
# City
# Abuja          2.003012  4021848  2019.0  30174  15.147590
# Lagos          2.023529  4118760  2019.0  29922  14.667647
# Port Harcourt  1.951220  3973392  2019.0  29364  14.920732
#
# [3 rows x 28 columns]

# %% [markdown]
# #### To-Do - Using the groupby object, display a table that shows the gross income of each city, and determine the city with the highest total gross income.

# %%
grossincome_city = by_city['gross income'].sum().reset_index()
grossincome_city
# Out:
#             City  gross income
# 0          Abuja   10923189.12
# 1          Lagos   10923466.68
# 2  Port Harcourt   11372781.24

# %%
grossincome_city.max().reset_index()
# Out:
#           index              0
# 0          City  Port Harcourt
# 1  gross income    11372781.24

# %% [markdown]
# ## Step 6 - Data Visualization

# %% [markdown]
# In this section, you will provide answer to some questions by generating charts and making use of different plotting styles. You will use the `Seaborn visualization` library to generate your plots. For all visualizations, include a chart title by using the seaborn `set_title` method

# %% [markdown]
# #### To-Do- Using `countplot`, determine the branch with the highest sales record. Optional - You can extend this to determine - most used payment method, city with the most sales

# %%
sns.countplot(x= 'Branch', data = combinefiles).set_title("Branch vs Sales", size = 25);

# %% [markdown]
# #### Explore a countplot for the `Payment` and `City` Column

# %%
sns.countplot(x = 'Payment', data = combinefiles).set_title('Most used payment card', size = 25);

# %%
sns.countplot(x = 'City', data = combinefiles).set_title('City with most sales', size = 25);

# %% [markdown]
# #### To-Do - Determine the highest & lowest sold product line, using Countplot
# Count Plot Tips- Set the `Product line` column to y-axis to prevent congestion on the x-axis

# %%
sns.countplot(y = 'Product line', data = combinefiles).set_title('Highest & lowest sold product line');

# %%
#Highest Product line sold: Fashion accessories
#Lowest Product line sold: Health and beauty

# %% [markdown]
# #### To-Do -  Determine the Payment channel used by most customer to pay for each product line. Count Plot Tips- Set the "product line" column to y-axis to prevent congestion on the x-axis, and use the "hue" parameter for the "Payment" column.

# %%
sns.countplot(y = 'Product line', data = combinefiles, hue = 'Payment').set_title('Payment used in Product line');

# %% [markdown]
# #### To-Do- Determine the Payment channel for each branch.
# Count Plot Tips - Use the hue parameter for the "branch" column

# %%
sns.countplot(x = 'Payment', data = combinefiles, hue = 'Branch').set_title('Payment channel for each branch')
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5), ncol=1)

# %% [markdown]
# #### To-Do- Determine the branch with the lowest rating. This you can determine using abox plot which gives a statistical summary of the plotted features, and you can pick out the branch with the lowest rating from the plot

# %%
sns.boxplot(x = 'Branch', y = 'Rating', data = combinefiles).set_title("Branch Rating");

# %%
#Branch B is the lowest rating

# %% [markdown]
# #### To-Do - The gender type often affects the kind of products being purchased at the supermarket.
# * Using a catplot() generate visualization for the "product line" on x-axis, quantity on the y-axis, and hue as gender.
# <br/>
#
# #### Set the aspect parameter to 4, so can you can effectively space out each product line.
#
#
#
# * Plot the same chart, but `Total Column` as the y-axis
#
# * Write a summary of the insights you can pick from this chart.

# %%
sns.catplot(x = 'Product line', y = 'Quantity', hue = 'Gender', kind= 'boxen', data = combinefiles, aspect = 4);

# %%
#Females consume more fashion products from Males while Males consume more food and beverages from Females.
#Males and females consume the same amount of sports and travel products.

# %% [markdown]
# #### To-Do -  An interesting insight to explore is the interaction of Unit price on the Quantity of goods purchased. To achieve this:
# * Use the `catplot()` to plot `Product line per unit price`, and `Product line per Quantity`. Set the kind parameter to `point`
# * In a new cell, Write a summary of the insights you uncovered

# %%
sns.catplot( x = 'Product line', y = 'Unit price', kind= 'point', data = combinefiles, aspect = 4);

# %%
sns.catplot( x = 'Product line', y = 'Quantity', kind= 'point', data = combinefiles, aspect = 4);

# %%
#Insights
#Fashion accessories has largest unit price but lowest Quantity
#Electronic accessories has the lowest unit price but highest Quantity

# %% [markdown]
# ## Step 7 - StandOut Section
# To make your submission standout,
# * You can continue to explore more insights that can be uncovered with different plotting methods.
# * Write a detailed summary on your approach, methods and insights.
# * Visit the [link](https://seaborn.pydata.org/tutorial/categorical.html) for more Seaborn visualization plots.

# %%
#Summary :
#I started by taking a online courses to learn the basics of data science and data analysis on Ustacky.
#I then read a few articles on the subject to gain a deeper understanding. 
#After that, I began working on this project to gain hands-on experience with various sources of information, such as Google.
#Through all of this, I have gained a good understanding of the data science process and the various methods and techniques used. 
#I have also gained some valuable insights into the field, which I believe will be helpful in my future career.

# %% [markdown]
# ## Step 8 - Documentation.
#
# * Write a detailed `ReadMe` that describes the project, explains important approach you followed to solve the tasks. Find a template in the starter file that can get you started quickly. Note: Do limit yourself to the template, you can include any interesting step that is worth sharing.
# * Write an Executive summary that you can present to `Company XYZ` management. The summary will explain your processes and insights you uncovered that can help the company
